# %%
import glob
import pickle
import pandas as pd
import numpy as np

# %%
models = glob.glob('../Train/*.pickle')
print(models)
# Out:
# ['../Train/TSF_CV_estimator.pickle', '../Train/SAXVSM_CV_estimator.pickle', '../Train/BOSSVS_CV_estimator.pickle', '../Train/LogisticReg_CV_estimator.pickle']

# %% [markdown]
# ## Logistic regression

# %%
with open(models[3], 'rb') as file:
        model_logi = pickle.load(file)

# %%
#'goes_class_num', 'Background_X-ray_flux' ,'relative_X-ray_flux_increase', 'fluorescence', 'Flare_rise_time', 'Flare_decay_time', 'Flare_duration', 'rise_gradient', 'decay_gradient', 'avg_fluorescence', 'avg_rise_fluorescence', 'avg_decay_fluorescence'
total_coef = np.zeros([1, 12])
for i in range(4):
    total_coef += model_logi['estimator'][i].coef_
total_coef /= 4

# %%
total_coef
# Out:
# array([[-62.27618581,   0.34999283,  36.37600745,  35.2269155 ,
#           0.06395739,   0.37464667,   2.49102648, -12.76038486,
#         -24.78729499, -36.66827984,  60.65155898,  29.44449471]])

# %% [markdown]
# ## Time Series Classifier

# %%
with open(models[0], 'rb') as file:
        model_tsf = pickle.load(file)

# %%
model_tsf['estimator'][0].n_features_in_
# Out:
# 138

# %%
with open('../Dataset_Creation/Timeseries_data.pickle', 'rb') as file:
        series = pickle.load(file)
        labels = pickle.load(file)

# %% [markdown]
# ## SAXVSM

# %%
with open(models[1], 'rb') as file:
        model_SAXVSM = pickle.load(file)

# %% [markdown]
# ## BOSSVS

# %%
with open(models[2], 'rb') as file:
        model_BOSSVS = pickle.load(file)

# %%
model_BOSSVS['estimator'][0]
# Out:
# BOSSVS(window_size=20, word_size=2)
